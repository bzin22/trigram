# %%
words = open('/Users/bzin/nn-zero-to-hero/data/names.txt', 'r').read().splitlines()

# %%
b = {}
for w in words: 
    chs = ['<S>'] + list(w) + ['<E>']
    for ch1, ch2 in zip(chs, chs[1:]):
        b[ch1] = b.get(ch1, 0) + 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 b = {}
# ----> 2 for w in words:
#       3     chs = ['<S>'] + list(w) + ['<E>']
#       4     for ch1, ch2 in zip(chs, chs[1:]):
#       5         b[ch1] = b.get(ch1, 0) + 1
#
# NameError: name 'words' is not defined

# %%
words = open('/Users/bzin/nn-zero-to-hero/data/names.txt', 'r').read().splitlines()

b = {}
for w in words: 
    chs = ['<S>'] + list(w) + ['<E>']
    for ch1, ch2 in zip(chs, chs[1:]):
        b[ch1] = b.get(ch1, 0) + 1

# %%
b
# Out:
# {'<S>': 32033,
#  'e': 20423,
#  'm': 6642,
#  'a': 33885,
#  'o': 7934,
#  'l': 13958,
#  'i': 17701,
#  'v': 2573,
#  's': 8106,
#  'b': 2645,
#  'p': 1026,
#  'h': 7616,
#  'c': 3532,
#  'r': 12700,
#  't': 5570,
#  'y': 9776,
#  'n': 18327,
#  'g': 1927,
#  'z': 2398,
#  'f': 905,
#  'd': 5496,
#  'u': 3135,
#  'k': 5040,
#  'w': 929,
#  'q': 272,
#  'x': 697,
#  'j': 2900}

# %%
b
# Out:
# {'<S>': 32033,
#  'e': 20423,
#  'm': 6642,
#  'a': 33885,
#  'o': 7934,
#  'l': 13958,
#  'i': 17701,
#  'v': 2573,
#  's': 8106,
#  'b': 2645,
#  'p': 1026,
#  'h': 7616,
#  'c': 3532,
#  'r': 12700,
#  't': 5570,
#  'y': 9776,
#  'n': 18327,
#  'g': 1927,
#  'z': 2398,
#  'f': 905,
#  'd': 5496,
#  'u': 3135,
#  'k': 5040,
#  'w': 929,
#  'q': 272,
#  'x': 697,
#  'j': 2900}
